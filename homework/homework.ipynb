# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r'C:\malware\data\cars.csv')
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
#show how many row ans columns in the data set
df.shape
# Out:
# (429, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         429 non-null    object
#  1   Model        429 non-null    object
#  2   Type         429 non-null    object
#  3   Origin       429 non-null    object
#  4   DriveTrain   429 non-null    object
#  5   MSRP         429 non-null    object
#  6   Invoice      429 non-null    object
#  7   EngineSize   429 non-null    float64
#  8   Cylinders    427 non-null    float64
#  9   Horsepower   429 non-null    int64
#  10  MPG_City     429 non-null    int64
#  11  MPG_Highway  429 non-null    int64
#  12  Weight       429 non-null    int64
#  13  Wheelbase    429 non-null    int64
#  14  Length       429 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.4+ KB

# %%
#how to get column names
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
#display top five rows
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
df.tail()#display last five rows
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 424  $40,083          2.3        5.0         242        20           26
# 425  $42,573          2.9        6.0         268        19           26
# 426  $24,641          1.9        4.0         170        22           29
# 427  $33,112          2.5        5.0         208        20           27
# 428  $33,112          2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 424    3450        105     186
# 425    3653        110     190
# ...

# %%
df.head(10)#display top 10 rows
# Out:
#     Make                    Model    Type  Origin DriveTrain      MSRP  \
# 0  Acura                      MDX     SUV    Asia        All  $36,945
# 1  Acura           RSX Type S 2dr   Sedan    Asia      Front  $23,820
# 2  Acura                  TSX 4dr   Sedan    Asia      Front  $26,990
# 3  Acura                   TL 4dr   Sedan    Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6  Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 7   Audi              A4 1.8T 4dr   Sedan  Europe      Front  $25,940
# 8   Audi   A41.8T convertible 2dr   Sedan  Europe      Front  $35,940
# 9   Audi               A4 3.0 4dr   Sedan  Europe      Front  $31,840
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0         265        17           23    4451
# ...

# %%
#remove unimportant columns msrp and invoice
df=df.drop(['MSRP','Invoice'],axis='columns')

# %%
#remove duplicate row if any and keep first row and remove other duplicate row of other row
df=df.drop_duplicates()
df
# Out:
#       Make                    Model   Type  Origin DriveTrain  EngineSize  \
# 0    Acura                      MDX    SUV    Asia        All         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 3    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 426  Volvo                      V40  Wagon  Europe      Front         1.9
# 427  Volvo                     XC70  Wagon  Europe        All         2.5
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
df.isnull().sum() #find the missing number in the columns
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
# remove the rows having missing values in cylinders
df.dropna(inplace=True)
df.dropna
# Out:
# <bound method DataFrame.dropna of       Make                    Model   Type  Origin DriveTrain  EngineSize  \
# 0    Acura                      MDX    SUV    Asia        All         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 3    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 426  Volvo                      V40  Wagon  Europe      Front         1.9
# 427  Volvo                     XC70  Wagon  Europe        All         2.5
#
# ...

# %%
#sort the data with respect to column npg_city in decending order
df=df.sort_values('MPG_City')
df['MPG_City'].head()
# Out:
# 118    10
# 166    10
# 114    12
# 412    12
# 216    12
# Name: MPG_City, dtype: int64

# %%
df['MPG_City'].tail()
# Out:
# 155    36
# 404    38
# 149    46
# 373    59
# 150    60
# Name: MPG_City, dtype: int64

# %%
#extract row 0 ,2,4 and column 1,3,5 using iloc
row1 = df.iloc([[0,2,4],[1,3,5]])


row1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26336\2623958472.py in <module>
#       1 #extract row 0 ,2,4 and column 1,3,5 using iloc
# ----> 2 row1 = df.iloc([[0,2,4],[1,3,5]])
#       3
#       4
#       5 row1
#
# E:\project demo\aa\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     632
#     633         if axis is not None:
# --> 634             axis = self.obj._get_axis_number(axis)
#     635         new_self.axis = axis
#     636         return new_self
#
# E:\project demo\aa\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     548     def _get_axis_number(cls, axis: Axis) -> int:
#     549         try:
# --> 550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
#     552             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ...

# %%
# select first five rows in mpg_city column using  iloc

df = df.iloc([[0:4],[8]])
df
# Out:
#   File "C:\Users\mishu\AppData\Local\Temp\ipykernel_26336\2931979125.py", line 3
#     df = df.iloc([[0:4],[8]])
#                     ^
# SyntaxError: invalid syntax

# %%
# #select only numerical type of columns
# df=df.select_datatype(include='int64')
# df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26336\150780759.py in <module>
#       1 #select only numerical type of columns
# ----> 2 df=df.select_datatype(include='int64')
#       3 df
#
# E:\project demo\aa\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'select_datatype'

# %%
#display summary satistics
df.discribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26336\4153249297.py in <module>
#       1 #display summary satistics
# ----> 2 df.discribe()
#
# E:\project demo\aa\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'discribe'

# %%
#create a box plot between origin and MPG_City 
df=pd.read_csv(r'C:\malware\data\cars.csv')
sns.boxplot(x='Origin',y='MPG_City',color='blue',data=df)
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='MPG_City'>

# %%
df.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  429.000000  427.000000  429.000000  429.000000   429.000000
# mean     3.195105    5.805621  215.867133   20.060606    26.843823
# std      1.107810    1.557103   71.753072    5.232095     5.734495
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.000000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   429.000000  429.000000  429.000000
# mean   3578.524476  108.156177  186.361305
# std     758.188346    8.302198   14.341219
# min    1850.000000   89.000000  143.000000
# 25%    3105.000000  103.000000  178.000000
# 50%    3476.000000  107.000000  187.000000
# 75%    3977.000000  112.000000  194.000000
# ...
